# %% [markdown]
# <a href="https://colab.research.google.com/github/Preethikuppuri/Preethikuppuri/blob/main/%20MINI%20AI-powered%20Resume%20Matching%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Create folders for files
os.makedirs("resumes", exist_ok=True)
os.makedirs("job_descriptions", exist_ok=True)

print("✅ Folders created. Ready to upload files!")
# Out:
# ✅ Folders created. Ready to upload files!

# %%
from google.colab import files

# Upload resumes
print("📤 Upload Resume Files")
resumes_uploaded = files.upload()

# Upload job descriptions
print("📤 Upload Job Description Files")
jobs_uploaded = files.upload()
# Out:
# 📤 Upload Resume Files
#      <input type="file" id="files-c8731c0e-c2b3-4082-922b-2f4d2ebd27dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8731c0e-c2b3-4082-922b-2f4d2ebd27dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !pip install pdfminer.six python-docx PyMuPDF
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 22.7 MB/s eta 0:00:00
# ...

# %%
import fitz  # for PDF
import docx

def extract_text(file_path):
    if file_path.endswith('.pdf'):
        text = ""
        with fitz.open(file_path) as doc:
            for page in doc:
                text += page.get_text()
        return text

    elif file_path.endswith('.docx'):
        doc = docx.Document(file_path)
        return "\n".join([para.text for para in doc.paragraphs])

    elif file_path.endswith('.txt'):
        with open(file_path, 'r', encoding='utf-8') as f:
            return f.read()

    else:
        return ""

# %%
import os

resume_texts = {}
for filename in os.listdir("resumes"):
    path = os.path.join("resumes", filename)
    text = extract_text(path)
    resume_texts[filename] = text

print("✅ Resumes processed!")
# Out:
# ✅ Resumes processed!

# %%
job_texts = {}
for filename in os.listdir("job_descriptions"):
    path = os.path.join("job_descriptions", filename)
    text = extract_text(path)
    job_texts[filename] = text

print("✅ Job Descriptions processed!")
# Out:
# ✅ Job Descriptions processed!

# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def preprocess(text):
    text = text.lower()
    text = ''.join([c for c in text if c not in string.punctuation])
    tokens = word_tokenize(text)
    filtered = [word for word in tokens if word not in stop_words]
    return " ".join(filtered)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Preprocess resumes
processed_resumes = {name: preprocess(text) for name, text in resume_texts.items()}

# Preprocess job descriptions
processed_jobs = {name: preprocess(text) for name, text in job_texts.items()}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

def match_resumes_to_jobs(resumes, jobs):
    results = []

    for job_name, job_text in jobs.items():
        corpus = [job_text] + list(resumes.values())
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(corpus)

        scores = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])[0]

        for i, (resume_name, _) in enumerate(resumes.items()):
            results.append({
                "Job": job_name,
                "Resume": resume_name,
                "Score": round(scores[i], 4)
            })

    return pd.DataFrame(results).sort_values(by='Score', ascending=False)

# %%
# 🔧 Create sample resume and job files inside Colab
resume_1 = """
John Doe
Email: john.doe@example.com
Skills: Python, Machine Learning, SQL, Data Analysis
Experience: 2 years at XYZ Corp as Data Analyst
"""

resume_2 = """
Jane Smith
Email: jane.smith@example.com
Skills: Java, Spring Boot, Microservices, AWS
Experience: 3 years at ABC Inc as Backend Developer
"""

job_desc = """
We are hiring a Data Analyst skilled in Python, SQL, and data visualization tools.
The candidate should have experience working with large datasets and analytics.
"""

# Write them into correct folders
with open("resumes/resume1.txt", "w") as f:
    f.write(resume_1)

with open("resumes/resume2.txt", "w") as f:
    f.write(resume_2)

with open("job_descriptions/job1.txt", "w") as f:
    f.write(job_desc)

print("✅ Sample resumes and job description created!")
# Out:
# ✅ Sample resumes and job description created!

# %%
resume_texts = {}
for filename in os.listdir("resumes"):
    path = os.path.join("resumes", filename)
    text = extract_text(path)
    resume_texts[filename] = text

job_texts = {}
for filename in os.listdir("job_descriptions"):
    path = os.path.join("job_descriptions", filename)
    text = extract_text(path)
    job_texts[filename] = text

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk

# Download everything you might need for NLTK processing
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
processed_resumes = {name: preprocess(text) for name, text in resume_texts.items()}
processed_jobs = {name: preprocess(text) for name, text in job_texts.items()}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

def match_resumes_to_jobs(resumes, jobs):
    results = []

    for job_name, job_text in jobs.items():
        # Combine the job + resumes into one corpus
        corpus = [job_text] + list(resumes.values())

        # TF-IDF vectorization
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(corpus)

        # Calculate cosine similarity between job and all resumes
        scores = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])[0]

        # Store results
        for i, (resume_name, _) in enumerate(resumes.items()):
            results.append({
                "Job Description": job_name,
                "Resume": resume_name,
                "Score": round(scores[i], 4)
            })

    # Return as a ranked DataFrame
    return pd.DataFrame(results).sort_values(by='Score', ascending=False)

# %%
df = match_resumes_to_jobs(processed_resumes, processed_jobs)
df.head(10)  # Top 10 best matches
# Out:
#   Job Description       Resume   Score
# 1        job1.txt  resume1.txt  0.3196
# 0        job1.txt  resume2.txt  0.0254

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Matching function
def match_resumes_to_jobs(resumes, jobs):
    results = []

    for job_name, job_text in jobs.items():
        # Combine job description and resumes into one list
        corpus = [job_text] + list(resumes.values())

        # Vectorize using TF-IDF
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(corpus)

        # Calculate similarity between job and each resume
        scores = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])[0]

        # Store the results
        for i, (resume_name, _) in enumerate(resumes.items()):
            results.append({
                "Job Description": job_name,
                "Resume": resume_name,
                "Score": round(scores[i], 4)
            })

    # Return ranked results
    return pd.DataFrame(results).sort_values(by='Score', ascending=False)

# Run the matching
df = match_resumes_to_jobs(processed_resumes, processed_jobs)
df.head(10)
# Out:
#   Job Description       Resume   Score
# 1        job1.txt  resume1.txt  0.3196
# 0        job1.txt  resume2.txt  0.0254
